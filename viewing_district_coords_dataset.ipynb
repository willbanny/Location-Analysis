# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data/district_coords.csv')

# %%
df.head()
# Out:
#                   District  POLYGON_ID    HECTARES  \
# 0                   Dorset      135743  252104.881
# 1    Barnsley District (B)       50242   32907.759
# 2  Birmingham District (B)       40111   26778.273
# 3      Dudley District (B)       40070    9796.363
# 4   Gateshead District (B)       50158   14405.779
#
#                                           SpatialObj   BR_Left     BR_Top  \
# 0  {"type":"Polygon", "coordinates":[[[-2.3191898... -2.961595  51.081001
# 1  {"type":"Polygon", "coordinates":[[[-1.3487315... -1.822590  53.612722
# 2  {"type":"Polygon", "coordinates":[[[-1.8725711... -2.033649  52.608706
# 3  {"type":"Polygon", "coordinates":[[[-2.1334928... -2.191946  52.558208
# 4  {"type":"Polygon", "coordinates":[[[-1.8206264... -1.852717  54.984412
#
#    BR_Right  BR_Bottom  Centroid_Lon  Centroid_Lat  Start_Lon  Start_Lat  \
# 0 -1.790622  50.512861     -2.333432     50.806317  -2.319190  51.080560
# ...

# %%
df.dtypes
# Out:
# District         object
# POLYGON_ID        int64
# HECTARES        float64
# SpatialObj       object
# BR_Left         float64
# BR_Top          float64
# BR_Right        float64
# BR_Bottom       float64
# Centroid_Lon    float64
# Centroid_Lat    float64
# Start_Lon       float64
# Start_Lat       float64
# End_Lon         float64
# End_Lat         float64
# dtype: object

# %%
p_samp = df.at[0, 'SpatialObj']

# %%
p_samp
# Out:
# '{"type":"Polygon", "coordinates":[[[-2.31918988003653,51.0805603459704], [-2.31918428109518,51.0805557752771], [-2.319182001385,51.0805564109561], [-2.31917470303436,51.0805538231768], [-2.31917126829815,51.0805525736618], [-2.31916740468453,51.0805512353971], [-2.31885992123601,51.0804492050234], [-2.31862592687555,51.0803634290305], [-2.31832903358532,51.0802648753081], [-2.31823554677746,51.080225834373], [-2.31814805508021,51.0801866871136], [-2.31813345305627,51.0801807021472], [-2.31810322754122,51.0801654978195], [-2.31806201943087,51.0801516722094], [-2.31776428855475,51.0800346854411], [-2.31774282039227,51.0800266509108], [-2.3177309424551,51.0800223669912], [-2.31772035852657,51.0800194283721], [-2.31770032405378,51.0800122891487], [-2.31765452043167,51.0799944294295], [-2.31762146420556,51.07998273961], [-2.31755264692721,51.0799604463531], [-2.31752818660944,51.0799532292102], [-2.3174652591605,51.0799363151769], [-2.31740220132197,51.0799211998924], [-2.31738217925513,
# ...

# %%
len(p_samp)
# Out:
# 1458111

# %%
print('Hello world')

# %%
df.drop(columns = ['SpatialObj']).to_csv('district_coords_clean.csv')

# %%
pd.read_csv('district_coords_clean.csv')
# Out:
#      Unnamed: 0                 District  POLYGON_ID    HECTARES   BR_Left  \
# 0             0                   Dorset      135743  252104.881 -2.961595
# 1             1    Barnsley District (B)       50242   32907.759 -1.822590
# 2             2  Birmingham District (B)       40111   26778.273 -2.033649
# 3             3      Dudley District (B)       40070    9796.363 -2.191946
# 4             4   Gateshead District (B)       50158   14405.779 -1.852717
# ..          ...                      ...         ...         ...       ...
# 358         358   Hillingdon London Boro       51011   11570.741 -0.510326
# 359         359     Test Valley District      122191   62765.805 -1.694119
# 360         360           Selby District       59823   60225.804 -1.352965
# 361         361        Ashfield District       48973   10954.591 -1.344593
# 362         362       Mansfield District       48816    7670.540 -1.260070
#
# ...

# %%
pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
